# %%
import pandas as pd
import math
import numpy as np
import re
import sys 
import os 

sys.path.append(os.getcwd())

# %%
product_catalogue = pd.read_csv("../data/processed/public/task_1_query-product_ranking/product_catalogue-v0.3.csv")

# %%
product_catalogue.shape
# Out:
# (883868, 7)

# %%
product_catalogue.product_description.to_list()
# Out:
# [nan,
# ...

# %%
product_catalogue.product_locale.value_counts()
# Out:
# us    482198
# jp    233852
# es    167818
# Name: product_locale, dtype: int64

# %%
product_catalogue.product_id.value_counts()
# Out:
# B07Q28DSYL    3
# B072J8XD3D    3
# B00P8XQPY4    3
# B07GK35P2C    3
# B00MH4QKP6    3
#              ..
# B07WKKDCPT    1
# B08KT518JX    1
# B001E1H7QY    1
# B005ACH8SU    1
# B09CNNHRQ1    1
# Name: product_id, Length: 879290, dtype: int64
